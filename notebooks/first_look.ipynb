# %%
import numpy as np
import pandas as pd
import functions

# %%
df = pd.read_csv("../data/raw/jobs_in_data.csv")
df2 = pd.read_csv("../data/raw/cost-of-living-by-country-2024.csv")

# %%
df2.head()
# Out:
#          country  NumbeoCoL2023  NumbeoCoLPlusRent2023  costOfLivingLC  \
# 0          India           22.9                   14.6           423.0
# 1          China           36.5                   26.6           752.0
# 2  United States           74.2                   61.0          1951.0
# 3      Indonesia           30.8                   20.5           548.0
# 4       Pakistan           17.6                   10.7           370.0
#
#    costOfLivingByCountry_cl_expatistan  costOfLivingByCountry_cl_globalEcon  \
# 0                                 59.0                                42.86
# 1                                115.0                                87.94
# 2                                187.0                               143.34
# 3                                 79.0                                54.52
# 4                                  NaN                                45.20
#
#    NumbeoLocalPurchasingPowerIndex2023
# 0                                 61.7
# ...

# %%
df3 = df2[['country', 'costOfLivingByCountry_cl_globalEcon']]
df3
# Out:
#            country  costOfLivingByCountry_cl_globalEcon
# 0            India                                42.86
# 1            China                                87.94
# 2    United States                               143.34
# 3        Indonesia                                54.52
# 4         Pakistan                                45.20
# ..             ...                                  ...
# 197         Monaco                                  NaN
# 198     San Marino                                  NaN
# 199          Palau                                  NaN
# 200          Nauru                                  NaN
# 201         Tuvalu                                  NaN
#
# [202 rows x 2 columns]

# %%
df = df.merge(df3, left_on='employee_residence', right_on='country', how='left')
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.isna().sum()
# Out:
# work_year                                 0
# job_title                                 0
# job_category                              0
# salary_currency                           0
# salary                                    0
# salary_in_usd                             0
# employee_residence                        0
# experience_level                          0
# employment_type                           0
# work_setting                              0
# company_location                          0
# company_size                              0
# country_x                                 1
# costOfLivingByCountry_cl_globalEcon_x    11
# country_y                                 1
# costOfLivingByCountry_cl_globalEcon_y    11
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#       work_year                      job_title               job_category  \
# 4450       2023                 Data Scientist  Data Science and Research
# 5412       2023                 Data Scientist  Data Science and Research
# 6551       2023                   Data Analyst              Data Analysis
# 6667       2022           Data Science Manager  Data Science and Research
# 8001       2021  Autonomous Vehicle Technician    Machine Learning and AI
# 8420       2022      Machine Learning Engineer    Machine Learning and AI
# 8421       2022      Machine Learning Engineer    Machine Learning and AI
# 8661       2022                  Data Engineer           Data Engineering
# 8662       2022                  Data Engineer           Data Engineering
# 9244       2021             Research Scientist  Data Science and Research
# 9260       2021             Lead Data Engineer           Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %% [markdown]
# ## Dataset overview:

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.shape
# Out:
# (9355, 12)

# %% [markdown]
# ## Missing values

# %%
df.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## Data Types

# %%
df.dtypes
# Out:
# work_year              int64
# job_title             object
# job_category          object
# salary_currency       object
# salary                 int64
# salary_in_usd          int64
# employee_residence    object
# experience_level      object
# employment_type       object
# work_setting          object
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# ## Check unique values

# %%
for col in df.columns:
    
    print(f'Unique values for {col}: ')
    print(df[col].unique())
    print()
# Out:
# Unique values for work_year:
# [2023 2022 2020 2021]
#
# Unique values for job_title:
# ['Data DevOps Engineer' 'Data Architect' 'Data Scientist'
#  'Machine Learning Researcher' 'Data Engineer' 'Machine Learning Engineer'
#  'Data Analyst' 'Analytics Engineer' 'Applied Scientist' 'BI Developer'
#  'Business Intelligence Engineer' 'Research Scientist' 'Research Analyst'
#  'Research Engineer' 'Data Science Engineer' 'Data Quality Analyst'
#  'Data Product Manager' 'Machine Learning Scientist' 'AI Engineer'
#  'MLOps Engineer' 'Deep Learning Engineer' 'Data Modeler'
#  'Data Product Owner' 'Data Science Consultant'
#  'Business Intelligence Analyst' 'AI Developer' 'Data Manager'
#  'ML Engineer' 'Data Science Director' 'Head of Data' 'BI Analyst'
#  'Data Management Analyst' 'Machine Learning Modeler' 'Data Specialist'
#  'BI Data Analyst' 'Data Integration Engineer'
#  'Business Intelligence Manager' 'Data Integration Specialist'
# ...

# %% [markdown]
# ## Check duplicates

# %%
df.duplicated(keep=False).sum()
# Out:
# 5455

# %%
df.drop_duplicates(keep="first", inplace=True)

# %%
df.shape[0]
# Out:
# 5341

# %%
0

# %%
df[df['job_category'] == 'Data Analysis']['job_title'].unique()
# Out:
# array(['Data Analyst', 'BI Data Analyst', 'Business Data Analyst',
#        'Financial Data Analyst', 'Insight Analyst', 'Staff Data Analyst',
#        'Business Intelligence Data Analyst', 'Finance Data Analyst',
#        'Compliance Data Analyst', 'Product Data Analyst',
#        'Sales Data Analyst', 'Lead Data Analyst',
#        'Marketing Data Analyst', 'Principal Data Analyst'], dtype=object)

# %%
for category in df['job_category'].unique():
    # Find unique job titles for each category
    unique_titles = df[df['job_category'] == category]['job_title'].unique()
    print(f"Unique job titles in {category}: {unique_titles}")
    print()
# Out:
# Unique job titles in Data Engineering: ['Data DevOps Engineer' 'Data Engineer' 'Data Integration Engineer'
#  'ETL Developer' 'Azure Data Engineer' 'Data Infrastructure Engineer'
#  'Principal Data Engineer' 'Consultant Data Engineer'
#  'Software Data Engineer' 'Cloud Data Engineer' 'ETL Engineer'
#  'Big Data Engineer' 'BI Data Engineer' 'Marketing Data Engineer'
#  'Lead Data Engineer']
#
# Unique job titles in Data Architecture and Modeling: ['Data Architect' 'Data Modeler' 'Data Strategist' 'Data Modeller'
#  'AWS Data Architect' 'Big Data Architect' 'Cloud Data Architect']
#
# Unique job titles in Data Science and Research: ['Data Scientist' 'Applied Scientist' 'Research Scientist'
#  'Research Analyst' 'Research Engineer' 'Data Science Engineer'
#  'Data Science Consultant' 'Data Science Director'
#  'Data Science Practitioner' 'AI Research Engineer' 'Data Science Manager'
#  'Director of Data Science' 'Decision Scientist'
# ...

# %%
df['job_category'].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)
